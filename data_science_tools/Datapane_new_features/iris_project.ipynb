# %%
from sklearn.datasets import load_iris
import plotly.express as px 
import datapane as dp

# %%
dp.login('YOUR_TOKEN')

# %%
X, y = load_iris(as_frame=True, return_X_y=True)
X.head(10)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# 5                5.4               3.9                1.7               0.4
# 6                4.6               3.4                1.4               0.3
# 7                5.0               3.4                1.5               0.2
# 8                4.4               2.9                1.4               0.2
# 9                4.9               3.1                1.5               0.1

# %%
fig = px.scatter(data_frame=X,
          x='sepal length (cm)',
          y='sepal width (cm)')

# %%
table = dp.DataTable(X)
plot = dp.Plot(fig)
# Out:
# Bokeh version 2.3.0 is not supported, your plots may not display correctly, please install version ~=2.2.0

# %%
group = dp.Group(table, plot,
                columns=2)

# %%
dp.Report(group).publish(name='Iris', description='Show Iris data')
# Out:
# Publishing report and associated data - please wait..
# Report successfully published at https://datapane.com/u/khuyentran1401/reports/iris/
