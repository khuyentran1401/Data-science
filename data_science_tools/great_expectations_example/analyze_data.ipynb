# %%
import pandas as pd

# %%
df = pd.read_csv('data/advertising.csv', parse_dates=['Timestamp'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   datetime64[ns]
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(3)
# memory usage: 78.2+ KB

# %%
df.head(10)
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
# 5                     59.99   23     59761.56                226.74
# 6                     88.91   33     53852.85                208.36
# 7                     66.00   48     24593.33                131.76
# 8                     74.53   30     68862.00                221.51
# 9                     69.88   20     55642.32                183.82
#
#                            Ad Topic Line              City  Male     Country  \
# 0     Cloned 5thgeneration orchestration       Wrightburgh     0     Tunisia
# ...

# %%
sort = df.sort_values(by='Timestamp')
first = sort[sort['Timestamp'].dt.month <= 4]
second = sort[sort['Timestamp'].dt.month > 4]

# %%
first["Daily Time Spent on Site"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
second
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 523                     67.94   43     68447.17                128.16
# 803                     41.84   49     37605.11                139.32
# 840                     72.46   40     56683.32                113.53
# 551                     81.95   31     64698.58                208.76
# 871                     76.79   27     55677.12                235.94
# ..                        ...  ...          ...                   ...
# 719                     67.59   45     58677.69                113.69
# 639                     74.06   23     40345.49                225.99
# 117                     61.88   42     60223.52                112.19
# 240                     80.03   44     24030.06                150.84
# 580                     69.15   46     36424.94                112.72
#
#                                 Ad Topic Line             City  Male  \
# ...

# %%
first.reset_index(drop=True).to_csv('first_data.csv')

# %%
second.reset_index(drop=True).to_csv('second_data.csv')
