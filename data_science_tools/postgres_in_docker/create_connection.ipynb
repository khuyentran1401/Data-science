# %%
# !pip install sqlalchemy psycopg2-binary
# Out:
# Requirement already satisfied: sqlalchemy in /Users/khuyen/Data-science/venv/lib/python3.9/site-packages (1.4.37)
# Collecting psycopg2-binary
#   Using cached psycopg2-binary-2.9.3.tar.gz (380 kB)
#   Preparing metadata (setup.py) ... done
# Using legacy 'setup.py install' for psycopg2-binary, since package 'wheel' is not installed.
# Installing collected packages: psycopg2-binary
#   Running setup.py install for psycopg2-binary ... done
# Successfully installed psycopg2-binary-2.9.3
# WARNING: There was an error checking the latest version of pip.

# %%
import pandas as pd
from sqlalchemy import create_engine, engine

# %%
# !wget https://raw.githubusercontent.com/mwaskom/seaborn-data/master/car_crashes.csv -O car_crashes.csv
# Out:
# --2022-06-07 14:04:20--  https://raw.githubusercontent.com/mwaskom/seaborn-data/master/car_crashes.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3301 (3.2K) [text/plain]
# Saving to: ‘car_crashes.csv’
#
# car_crashes.csv     100%[===================>]   3.22K  --.-KB/s    in 0s
#
# 2022-06-07 14:04:21 (19.2 MB/s) - ‘car_crashes.csv’ saved [3301/3301]

# %%
engine = create_engine('postgresql://postgres:123456@localhost:5432/car_crashes', )
engine.connect()

# %%
df = pd.read_csv('car_crashes.csv')

# %%
df.to_sql(name="car_crashes", con=engine, index=False, if_exists="replace")
# Out:
# 51

# %%
query = """
SELECT * FROM car_crashes LIMIT 5
"""

# %%
pd.read_sql(query, con=engine)
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA
